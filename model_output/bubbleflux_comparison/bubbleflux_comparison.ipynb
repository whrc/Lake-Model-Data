# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
######## bubble flux on ###########
on_co2 = 'YKD-burned_bubble/co2_water  1  1f2.dat'
on_co2_bubble = 'YKD-burned_bubble/fbblflx_co2  1  1f2.dat'
on_ch4 = 'YKD-burned_bubble/methane_water  1  1f2.dat'
on_ch4_bubble = 'YKD-burned_bubble/fbblflx_ch4  1  1f2.dat'
on_ch4_soil = 'YKD-burned_bubble/methane_water_soil  1  1f2.dat'
on_doc = 'YKD-burned_bubble/DOC  1  1f2.dat'

# %%
######## bubble flux off ###########
off_co2 = 'YKD-burned_nobubble/co2_water  1  1f2.dat'
off_co2_bubble = 'YKD-burned_nobubble/fbblflx_co2  1  1f2.dat'
off_ch4 = 'YKD-burned_nobubble/methane_water  1  1f2.dat'
off_ch4_bubble = 'YKD-burned_nobubble/fbblflx_ch4  1  1f2.dat'
off_ch4_soil = 'YKD-burned_nobubble/methane_water_soil  1  1f2.dat'
off_doc = 'YKD-burned_nobubble/DOC  1  1f2.dat'

# %%
df_on_ch4 = pd.read_csv(on_ch4, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_on_ch4.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'ch4']
df_on_ch4['datetime'] = pd.to_datetime({'Year': df_on_ch4['year'], 'Month': df_on_ch4['month'], 'Day':df_on_ch4['day']})
df_on_ch4 = df_on_ch4[df_on_ch4['ch4']!=-999]

df_off_ch4 = pd.read_csv(off_ch4, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_off_ch4.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'ch4']
df_off_ch4['datetime'] = pd.to_datetime({'Year': df_off_ch4['year'], 'Month': df_off_ch4['month'], 'Day':df_off_ch4['day']})
df_off_ch4 = df_off_ch4[df_off_ch4['ch4']!=-999]

# %%
sns.lineplot(data=df_on_ch4, x='datetime', y='ch4', label='bubble on')
sns.lineplot(data=df_off_ch4, x='datetime', y='ch4', label='bubble off')
# Out:
# <AxesSubplot: xlabel='datetime', ylabel='ch4'>

# %%
df_on_ch4_bubble = pd.read_csv(on_ch4_bubble, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_on_ch4_bubble.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'ch4_bubble']
df_on_ch4_bubble['datetime'] = pd.to_datetime({'Year': df_on_ch4_bubble['year'], 'Month': df_on_ch4_bubble['month'], 'Day':df_on_ch4_bubble['day']})
df_on_ch4_bubble = df_on_ch4_bubble[df_on_ch4_bubble['ch4_bubble']!=-999]

df_off_ch4_bubble = pd.read_csv(off_ch4_bubble, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_off_ch4_bubble.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'ch4_bubble']
df_off_ch4_bubble['datetime'] = pd.to_datetime({'Year': df_off_ch4_bubble['year'], 'Month': df_off_ch4_bubble['month'], 'Day':df_off_ch4_bubble['day']})
df_off_ch4_bubble = df_off_ch4_bubble[df_off_ch4_bubble['ch4_bubble']!=-999]

# %%
sns.lineplot(data=df_on_ch4_bubble, x='datetime', y='ch4_bubble', label='bubble on')
sns.lineplot(data=df_off_ch4_bubble, x='datetime', y='ch4_bubble', label='bubble off')

# %%
df_on_co2 = pd.read_csv(on_co2, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_on_co2.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'co2']
df_on_co2['datetime'] = pd.to_datetime({'Year': df_on_co2['year'], 'Month': df_on_co2['month'], 'Day':df_on_co2['day']})
df_on_co2 = df_on_co2[df_on_co2['co2']!=-999]

df_off_co2 = pd.read_csv(off_co2, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_off_co2.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'co2']
df_off_co2['datetime'] = pd.to_datetime({'Year': df_off_co2['year'], 'Month': df_off_co2['month'], 'Day':df_off_co2['day']})
df_off_co2 = df_off_co2[df_off_co2['co2']!=-999]

# %%
sns.lineplot(data=df_on_co2, x='datetime', y='co2', label='bubble on')
sns.lineplot(data=df_off_co2, x='datetime', y='co2', label='bubble off')

# %%
df_on_co2_bubble = pd.read_csv(on_co2_bubble, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_on_co2_bubble.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'co2_bubble']
df_on_co2_bubble['datetime'] = pd.to_datetime({'Year': df_on_co2_bubble['year'], 'Month': df_on_co2_bubble['month'], 'Day':df_on_co2_bubble['day']})
df_on_co2_bubble = df_on_co2_bubble[df_on_co2_bubble['co2_bubble']!=-999]

df_off_co2_bubble = pd.read_csv(off_co2_bubble, delimiter=r"\s+", skiprows=7, index_col=None, header=None)
df_off_co2_bubble.columns=['year', 'month', 'day', 'hour', 'integration_time', 'depth', 'co2_bubble']
df_off_co2_bubble['datetime'] = pd.to_datetime({'Year': df_off_co2_bubble['year'], 'Month': df_off_co2_bubble['month'], 'Day':df_off_co2_bubble['day']})
df_off_co2_bubble = df_off_co2_bubble[df_off_co2_bubble['co2_bubble']!=-999]

# %%
sns.lineplot(data=df_on_co2_bubble, x='datetime', y='co2_bubble', label = 'bubble on')
sns.lineplot(data=df_off_co2_bubble, x='datetime', y='co2_bubble', label = 'bubble off')
plt.yscale('log')
