# %%
import shutil
import multiprocessing
import ast
import subprocess
import re
import os
import shlex
from functools import partial
import numpy as np
from scipy.stats import loguniform
class log_wrapper:
    def __init__(self, cmdline, tag):
        self.cmdline = cmdline
        self.tag = tag

    def __enter__(self):
        print(f"Running: {self.cmdline}")

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print(f"Error occurred in {self.tag}: {exc_value}")
        else:
            print(f"{self.tag} completed successfully.")
class SensitivityAnalysis():
    def __init__(self,setup_folder = "setup"):
        self.file_setup = "setup/YKD-burned_setup.dat"
        self.file_driver = "setup/YKD-burned_driver.dat"
        self.file_data = "data/YKD-burned.dat"
        self.number = 0
        self.target_string = ""
        self.file_list = []
        self.target_values = []
        self.dictionaries = []
        self.list_of_modifies_files = []
        self.setup_folder = setup_folder

#     @staticmethod
#     def write_dictionary_to_file(dictionary, filename):
#         with open(filename, 'w') as file:
#             for key, value in dictionary.items():
#                 # Convert key and value to strings if they are not already
#                 key_str = str(key)
#                 value_str = str(value)

#                 # Add single quotes around the value if it contains space

#                 # Write the key-value pair as a single line in the file
#                 file.write(f"{key_str}" + " " + f"{value_str}\n")
#         file.close()


    def create_files(self):
        self.number = len(self.list_of_modifies_files)
        for i, (setup_file, driver_file) in enumerate(self.list_of_modifies_files):
            setup_filename = f"setup/YKD{i}_setup.dat"
            driver_filename = f"setup/YKD{i}_driver.dat"

            self.write_dictionary_to_file(setup_file, setup_filename)
            self.write_dictionary_to_file(driver_file, driver_filename)

        return self.file_list
    def _copy_files(self,args):
        source_file,destination_file = args
        with open(source_file, "r") as setup_file, open(destination_file, "w") as new_setup_file:
            shutil.copyfileobj(setup_file, new_setup_file)
    def create_files_single(self, source_directory, destination_directory,experiment_name):
        if not os.path.exists(destination_directory):
            os.makedirs(destination_directory)

        

        print(f"Copying files from {source_directory} to {destination_directory}")

        for filename in os.listdir(source_directory):
            source_path = os.path.join(source_directory, filename)
            destination_path = os.path.join(destination_directory, filename)

            if source_path == destination_path:
                print(f"Skipping copying {source_path} to {destination_path} as it's the same file.")
                continue

            print(f"Copying {source_path} to {destination_path}")

            # If the item is a file, copy it to the destination directory
            if os.path.isfile(source_path):
                shutil.copy2(source_path, destination_path)

            # If the item is a directory, recursively call create_files_single
            elif os.path.isdir(source_path):
                self.create_files_single(source_path, destination_directory,experiment_name)
#     def create_files_single(self, source_directory, destination_directory):

#         shutil.copytree(source_directory, destination_directory)
#     @staticmethod
#     def process_file(file_path):
#         with open(file_path, 'r') as file:
#             lines = file.readlines()

#         dictionary = {}
#         for line in lines:
#             line = line.strip()
#             if not line or line.startswith("#"):
                
#                 continue
#             elif line == "end":
#                 # Include "end" as a key without any associated value
#                 dictionary["end"] = "\n"

#                 break  # Stop processing further lines after encountering "end"
#             else:
#                 # Using regular expression to extract key and value parts
#                 match = re.match(r"^(\S+)\s+(.*)$|(.*)", line)

#                 number = match.groups()
#                 print(number)
#                 non_none_groups = [group for group in match.groups() if group is not None]
#                 print(non_none_groups)
#                 if match:
#                     key = match.group(1)
#                     value = match.group(2).strip()
#                     dictionary[key] = value
# #                 if match.group(3):
# #                     remaining_text = match.group(3)
# #                     dictionary[key]  = ' '.join([value, remaining_text])
                   

#         return dictionary

   





    def create_data_file(self):
        try:
            if not os.path.exists("data"):
                os.makedirs("data")

            for i, (setup_file, driver_file) in enumerate(self.list_of_modifies_files):
                data_filename = os.path.join("data", f"YKD{i}.dat")
                self._copy_files((self.file_data, data_filename))

            print("Data files created successfully.")
        except Exception as e:
            raise ValueError(f"Error creating data files: {e}")
    def generate_and_write_files(self, num_files):
        """
        Generate and write tuples of driver and setup files to the "setup" folder.

        Args:
        num_files (int): The number of tuples to generate.
        """
        if not os.path.exists(self.setup_folder):
            os.makedirs(self.setup_folder)

        for i in range(num_files):
            setup_folder = f"LAKE{i}/setup"
            setup_filename = os.path.join(setup_folder, f"YKD{i}_setup.dat")
            driver_filename = os.path.join(setup_folder, f"YKD{i}_driver.dat")

            # Copy the content from the original setup and driver files to the new files
            with open(self.file_setup, "r") as src_setup_file, open(setup_filename, "w") as dst_setup_file:
                for line in src_setup_file:
                    dst_setup_file.write(line.replace("\t", " "))  # Replace tabs with spaces

            with open(self.file_driver, "r") as src_driver_file, open(driver_filename, "w") as dst_driver_file:
                for line in src_driver_file:
                    dst_driver_file.write(line.replace("\t", " "))  # Replace tabs with spaces

            # Append the tuple of filenames to the list_of_modifies_files
            self.list_of_modifies_files.append((setup_filename, driver_filename))


    def find_target(self, targets, new_values,number,filename):
        """
        Search for the specified target string in the setup and driver files and change its value.

        Args:
            target (str): The string to search for in the setup and driver files.
            new_values (list): A list of new values corresponding to each file in self.list_of_modifies_files.
        """
        print(new_values)
        # Make a copy of the new_values list to avoid modifying the original list
        if number != len(self.list_of_modifies_files):
            raise ValueError(f"Number of new values({len(new_values)}) must be equal to the number of files in self.list_of_modifies_files({len(self.list_of_modifies_files)}).")
        for (setup_file, driver_file), target_value,file in zip(self.list_of_modifies_files, new_values,filename):
            print(target_value)
#             print(targets)
            for target in targets:
#                 print(target)
#                 print(target_value)
                self.process_file_and_update_value(setup_file, target,target_value)

                self.process_file_and_update_value(driver_file, target, target_value)

    def process_file_and_update_value(self, file_path, target, new_value):
        """
        Process the specified file, search for the target string, and update its value.

        Args:
            file_path (str): The path of the file to process.
            target (str): The string to search for in the file.
            new_value (str): The new value to replace the found target string.
        """
        with open(file_path, 'r') as file:
            lines = file.readlines()

        with open(file_path, 'w') as file:
            for line in lines:
                line = line.strip()

                if line.startswith("#"):
                    # Skip lines starting with #
                    file.write(line + "\n")
                elif line.startswith("end"):
                    # Stop processing further lines after encountering "end"
                    file.write(line + "\n")
                    break
                elif target in line:
                    file.write(f"{target} {new_value}\n")
                else:
                    # Copy the line as is
                    file.write(line + "\n")
#     def transform_to_dictionary(self):
#         try:
#             file_paths = [self.file_setup,self.file_driver]
#             with multiprocessing.Pool() as pool:
#                 self.dictionaries = pool.map(self.process_file, file_paths)
#             return self.dictionaries

#         except Exception as e:
#             raise ValueError(f"Error converting file '{self.file_setup}' or {self.file_driver} to a dictionary: {e}")
#     def target_argument(self,target,target_values):
        
#         self.target_string = target
#         self.target_values = target_values
#         self.target_values = target_values
#         for dictionary in self.dictionaries:
#             temp_list = []

#             if self.target_string in dictionary and dictionary ==  self.dictionaries[0]:
#                 for value in self.target_values:
#                     updated_dict = dictionary.copy()
#                     updated_dict[self.target_string] = value
#                     self.list_of_modifies_files.append((updated_dict,self.dictionaries[1]))

                    
#             if self.target_string in dictionary and dictionary == self.dictionaries[1]:
#                  for value in self.target_values:
#                     updated_dict = dictionary.copy()
#                     updated_dict[self.target_string] = value
                    
#                     self.list_of_modifies_files.append((self.dictionaries[0],updated_dict))
#         return self.list_of_modifies_files
#     def run_model(self,run_name):
#         program = '/home/kgurbanov/'
#         cmdline = program + ' ' + './launch ' + ' ' + run_name

#         with log_wrapper(cmdline, tag='run') as lw:
#             completed_process = subprocess.run(
#                 cmdline,             # The program + options
#                 shell=True,          # must be used if passing options as str and not list
#                 check=True,          # raise CalledProcessError on failure
#                 #capture_output=True, # collect stdout and stderr; causes memory problems I think
#                 stdout=subprocess.DEVNULL,
#                 stderr=subprocess.DEVNULL,
#                 cwd=rundirectory    # control context
#             )

#             if not completed_process.returncode == 0:
#                 print(completed_process.stdout)
#                 print(completed_process.stderr)

    def read_file_path(self, filename):
        # Read the file and return the content as a string
        with open(filename, 'r') as file:
            content = file.read().strip()
        return content
    @staticmethod
    def create_directory(directory):
        os.makedirs(directory, exist_ok=True)
        print(f"Directory created: {directory}")
    def create_project_parallel(self, project_name,project_directory):
    # Determine the operating system
        
        if os.name == "posix":
            print("Operating system: Linux or macOS")
            OS = "linux" if os.uname().sysname == "Linux" else "OSX"
        else:
            print("Unknown operating system")
            return

        directories = [
            f"{project_directory}/results/{project_name}/everystep",
            f"{project_directory}/results/{project_name}/netcdf",
            f"{project_directory}/results/{project_name}/time_series",
            f"{project_directory}/results/{project_name}/hourly",
            f"{project_directory}/results/{project_name}/monthly",
            f"{project_directory}/results/{project_name}/daily",
        ]
        print(directories)

        with multiprocessing.Pool() as pool:
            pool.map(self.create_directory, directories)
        
        # Modify driver file
        setup_folder = f"/home/kgurbanov/{project_directory}"
        driver_file_path = os.path.join(setup_folder, "driver_file.dat")
        if OS == "linux":
            sed_command = f"sed -i '2d' {driver_file_path} && sed -i \"\\$a setup/{project_name}_driver.dat\" {driver_file_path}"
        elif OS == "OSX":
            sed_command = f"sed -i '' '2d' {driver_file_path} && sed -i '' '$ a\\setup/{project_name}_driver.dat' {driver_file_path}"
        os.system(sed_command)

        # Modify setup file
        setup_file_path = os.path.join(setup_folder, "setup_file.dat")
        if OS == "linux":
            sed_command = f"sed -i '2d' {setup_file_path} && sed -i \"\\$a setup/{project_name}_setup.dat\" {setup_file_path}"
        elif OS == "OSX":
            sed_command = f"sed -i '' '2d' {setup_file_path} && sed -i '' '$ a\\setup/{project_name}_setup.dat' {setup_file_path}"
        os.system(sed_command)

        # Check if necessary files exist
        def check_file(file_path):
            if not os.path.isfile(file_path):
                print(f"Warning: The file {file_path} does not exist")

        check_file(f"./setup/{project_name}_setup.dat")
        check_file(f"./setup/{project_name}_driver.dat")
        check_file(f"./data/{project_name}.dat")

        print("Project for LAKE model created successfully.")
#     def write_to_datfiles(self,project_name):
#         if os.name == "posix":
#             print("Operating system: Linux or macOS")
#             OS = "linux" if os.uname().sysname == "Linux" else "OSX"
#         else:
#             print("Unknown operating system")
#             return
#         driver_file_path = f"setup/{project_name}_driver.dat"
#         setup_file_path = f"setup/{project_name}_setup.dat"

#         if OS == "linux":
#             with open("driver_file.dat", "w") as file:
#                 file.write(driver_file_path)

#             with open("setup_file.dat", "w") as file:
#                 file.write(setup_file_path)
#         elif OS == "OSX":
#             with open("driver_file.dat", "w") as file:
#                 file.write(driver_file_path)

#             with open("setup_file.dat", "w") as file:
#                 file.write(setup_file_path)

        
    #create multiple projects
    def create_multiple_projects(self,project_names,project_directories):
        processes = []
        for project_name,project_directory in zip(project_names,project_directories):
            process = multiprocessing.Process(target=self.create_project_parallel, args=(project_name,project_directory))
            process.daemon = False  # Set daemon to False to avoid the AssertionError
            processes.append(process)

        for process in processes:
            process.start()

        for process in processes:
            process.join()

        print("All projects created successfully.")
    def run_experiment(self, experiment_name,rundirectory,project_directory):
        if experiment_name:
            os.makedirs(f"results/{experiment_name}", exist_ok=True)

        self.run_model(rundirectory,project_directory)

        if experiment_name:
            basename = experiment_name.rsplit("_", 1)[0]
            source_directory = f"results/{basename}"
            destination_directory = f"results/{experiment_name}"

            print(f"Copying files from {source_directory} to {destination_directory}")

            # Copy files from source_directory to destination_directory
            self.create_files_single(source_directory, destination_directory, experiment_name)
    def generate_samples_for_SA(self, p_name, p_initial, perturbation, logparams, N, seed=''):
        params = []  # Dictionary of parameters

        for name, init in zip(p_name, p_initial):
            p_bounds = [init - (init * perturbation), init + (init * perturbation)]
            params.append(dict(name=name, bounds=p_bounds, initial=init))

        # Set random seed if provided
        if seed != '':
            np.random.seed(int(seed))

        l = np.random.uniform(size=(N, len(params)))

        # Generate bounds, based on specification in params list
        lows = np.array([p['bounds'][0] for p in params])
        highs = np.array([p['bounds'][1] for p in params])

        # Figure out the spread, or difference between bounds
        spreads = highs - lows

        # Generate the sample matrix
        sm = l * spreads + lows

        # Apply loguniform for small param values only
        if len(logparams) > 0:
            inum = 0
            for ilog, p in zip(logparams, params):
                if ilog:
                    sm[:, inum] = loguniform.rvs(p['bounds'][0], p['bounds'][1], size=N)
                inum += 1

        return sm

    def run_experiment_parallel(self, experiment_names,rundirectory,project_directories):
        processes = []
        for experiment_name,project_directory in zip(experiment_names,project_directories):
            process = multiprocessing.Process(target=self.run_experiment, args=(experiment_name, rundirectory,project_directory))
            processes.append(process)

        for process in processes:
            process.start()

        for process in processes:
            process.join()
           


        print("All experiments completed successfully.")
    def run_model(self,rundirectory,project_directory):
        program_path = "./lake.out"
        print(project_directory)
        run_d = os.path.join(rundirectory,f"{project_directory}")
        try:
            completed_process = subprocess.run(
                program_path,
                shell=True,
                check=True,
                cwd=run_d,
                stdout=subprocess.PIPE,  # Capture standard output
                stderr=subprocess.PIPE,  # Capture standard error
                text=True               # Return output as text
            )

            print("Model run completed successfully.")
            print("Standard Output:")
            print(completed_process.stdout)

        except subprocess.CalledProcessError as e:
            print(f"Error occurred during model run. Exit code: {e.returncode}")
            print("Standard Output:")
            print(e.stdout)
            print("Standard Error:")
            print(e.stderr)
            raise e
    def clear(self):
        return self.list_of_modifies_files.clear()

# %%
sensitivity = SensitivityAnalysis()
p_name = ['khsO2', 'r0methprod']
p_initial = [1, 2, 3]
perturbation = 0.75
logparams = np.zeros(len(p_initial))
logparams[1] = 1
N = 2
seed = ''
samples = sensitivity.generate_samples_for_SA(p_name, p_initial, perturbation, logparams, N, seed)
target_values = samples.tolist()
print(target_values)
new_target_values = []
for i in target_values:
    new_target_values = i

# Now, target_values should look like this:
# [[param_value_1_for_target_YKD0, param_value_2_for_target_YKD0],
#  [param_value_1_for_target_YKD1, param_value_2_for_target_YKD1]]

number = sum(len(target_values[i]) for i in range(len(target_values)))
print(number)
# Out:
# [[1.3696249030056973, 1.231457247513021], [1.587768805960707, 2.9342868996731823]]
# 4

# %%
sensitivity.clear()
sensitivity.generate_and_write_files(number)
filename = ["setup","driver"]
directory  = ["LAKE0","LAKE1"]
sensitivity.create_data_file()
sensitivity.find_target(["dataname"],["'YKD0'","'YKD1'"],number,["driver","setup"])
list_of_modified_files = sensitivity.find_target(p_name, new_target_values,number,filename)
folder = ["YKD0","YKD1"]
rundirectory = os.path.abspath(os.getcwd())
# sensitivity.create_project_parallel(folder)
sensitivity.create_multiple_projects(folder,directory)
sensitivity.run_experiment_parallel(folder, rundirectory,directory)
# Out:
# Data files created successfully.
# ["'YKD0'", "'YKD1'"]
# 'YKD0'
# 'YKD1'
# [0.9805012434331632, 2.104583577164602]
# 0.9805012434331632
# 2.104583577164602
# Operating system: Linux or macOS
# ['LAKE0/results/YKD0/everystep', 'LAKE0/results/YKD0/netcdf', 'LAKE0/results/YKD0/time_series', 'LAKE0/results/YKD0/hourly', 'LAKE0/results/YKD0/monthly', 'LAKE0/results/YKD0/daily']
# Operating system: Linux or macOS
# ['LAKE1/results/YKD1/everystep', 'LAKE1/results/YKD1/netcdf', 'LAKE1/results/YKD1/time_series', 'LAKE1/results/YKD1/hourly', 'LAKE1/results/YKD1/monthly', 'LAKE1/results/YKD1/daily']
# Directory created: LAKE0/results/YKD0/everystep
# Directory created: LAKE1/results/YKD1/netcdf
# Directory created: LAKE1/results/YKD1/hourly
# Directory created: LAKE1/results/YKD1/everystep
# Directory created: LAKE1/results/YKD1/daily
# Directory created: LAKE0/results/YKD0/time_series
# Directory created: LAKE0/results/YKD0/monthly
# Directory created: LAKE0/results/YKD0/netcdf
# Directory created: LAKE0/results/YKD0/daily
# Directory created: LAKE1/results/YKD1/time_series
# Directory created: LAKE0/results/YKD0/hourly
# Directory created: LAKE1/results/YKD1/monthly
# Project for LAKE model created successfully.
# Project for LAKE model created successfully.
# All projects created successfully.
# LAKE0
# LAKE1
# Model run completed successfully.
# Standard Output:
#  Format of input file      =            0
#  The number of points      =            1
#  Switch for lake interact. =            1
#  Format of ASCII file      =            0
#  Height of t&q measur-ts   =    2.0000000000000000
#  Height of wind measur-ts  =    2.0000000000000000
#  Time interval of input    =    24.000000000000000
#  Input of radiation        =            1
#  N_header_lines            =            1
#  N_Coloumns                =           11
#  N_Year                    =            1
#  N_Month                   =            2
#  N_Day                     =            3
#  N_Hour                    =           -1
#  N_Uspeed                  =            4
#  N_Vspeed                  =            5
#  N_Temp                    =            6
#  N_Hum                     =            7
#  N_Pres                    =            8
#  N_SWdown                  =            9
#  N_LWdown                  =           10
#  N_NetRad                  =           -1
#  N_Precip                  =           11
#  N_SensFlux                =           -1
#  N_LatentFlux              =           -1
#  N_Ustar                   =           -1
#  N_surfrad                 =           -1
#  N_cloud                   =           -1
#  N_SurfTemp                =           -1
#  The year of start integr. =         2022
#  The month of start integ. =            1
#  The day of start integ.   =            1
#  Initial hour              =    12.000000000000000
#  Integration time, days    =    365.00000000000000
#  Spinup, days              =            0
#  Spinup period, days       =    0.0000000000000000
#  Timestep, sec             =    20.000000000000000
#  The year of start integr. =            0
#  Switch for control point  =            1
#  Contr. point period, days =    10.000000000000000
#  The rad extinct in water  =    1.0400000000000000
#  The rad extinction in ice =    1.0000000000000000
#  The x-slope angle         =    0.0000000000000000
#  The y-slope angle         =    0.0000000000000000
#  a_veg                     =   0.29999999999999999
#  c_veg                     =    1.0000000000000000E-003
#  The vegetation height     =    0.0000000000000000
#  The Coriolis parameter    =   -999.00000000000000
#  Latitude, deg             =    61.000000000000000
#  Longitude, deg            =   -163.00000000000000
#  The fetch, m              =    100.00000000000000
#  Init. ice thickness, m    =   0.14080000000000001
#  Init. depth of lake, m    =    1.5000000000000000
#  Init. deep ice thick., m  =    0.0000000000000000
#  Init. snow depth, m       =   0.79339999999999999
#  Init. temp. at lake surf. =   -1.7253080000000000E-004
#  Init. temp. at lake bot.  =   -2.3350130000000001E-005
#  Init. temp. at soil bot.  =    1.5100000000000001E-002
#  Mean coloumn temperature  =    3.0000000000000000
#  Init. mixed layer depth   =    0.0000000000000000
#  Init. surface salinity    =    1.5327680000000000E-013
#  Init. bottom salinity     =    1.5327680000000000E-013
#  Init. surface X-speed     =    1.0000000000000001E-005
#  Init. surface Y-speed     =    0.0000000000000000
#  Switch for temp. init.    =            3
#  The area of lake, m**2    =    818.00000000000000
#  The ellipse aspect ratio  =    20.000000000000000
#  The lake form             =            2
#  Tributary inflow, m**3/s  =   -9999.0000000000000
#  Order of outflow dep.     =            0
#  Number of morphom. depths =            6
#  Nstep for netcdf output   =           -1
#  Nstep for Flake output    =            3
#  Moving average window     =           -1
#  Mean cycle period         =           -1
#                  timestep               N of point      Surface temperature
#                      1000                        1                    257.0
#     Year   Month     Day    Hour  Months
#     2022       1       1   17.56    0.01
#                  timestep               N of point      Surface temperature
#                      2000                        1                    256.6
#     Year   Month     Day    Hour  Months
#     2022       1       1   23.11    0.02
#                  timestep               N of point      Surface temperature
#                      3000                        1                    256.4
#     Year   Month     Day    Hour  Months
#     2022       1       2    4.67    0.02
#                  timestep               N of point      Surface temperature
#                      4000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022       1       2   10.22    0.03
#                  timestep               N of point      Surface temperature
#                      5000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022       1       2   15.78    0.04
#                  timestep               N of point      Surface temperature
#                      6000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022       1       2   21.33    0.05
#                  timestep               N of point      Surface temperature
#                      7000                        1                    256.2
#     Year   Month     Day    Hour  Months
#     2022       1       3    2.89    0.05
#                  timestep               N of point      Surface temperature
#                      8000                        1                    256.3
#     Year   Month     Day    Hour  Months
#     2022       1       3    8.44    0.06
#                  timestep               N of point      Surface temperature
#                      9000                        1                    256.4
#     Year   Month     Day    Hour  Months
#     2022       1       3   14.00    0.07
#                  timestep               N of point      Surface temperature
#                     10000                        1                    256.6
#     Year   Month     Day    Hour  Months
#     2022       1       3   19.56    0.08
#                  timestep               N of point      Surface temperature
#                     11000                        1                    256.5
#     Year   Month     Day    Hour  Months
#     2022       1       4    1.11    0.08
#                  timestep               N of point      Surface temperature
#                     12000                        1                    256.6
#     Year   Month     Day    Hour  Months
#     2022       1       4    6.67    0.09
#                  timestep               N of point      Surface temperature
#                     13000                        1                    256.8
#     Year   Month     Day    Hour  Months
#     2022       1       4   12.22    0.10
#                  timestep               N of point      Surface temperature
#                     14000                        1                    256.6
#     Year   Month     Day    Hour  Months
#     2022       1       4   17.78    0.11
#                  timestep               N of point      Surface temperature
#                     15000                        1                    256.5
#     Year   Month     Day    Hour  Months
#     2022       1       4   23.33    0.11
#                  timestep               N of point      Surface temperature
#                     16000                        1                    256.3
#     Year   Month     Day    Hour  Months
#     2022       1       5    4.89    0.12
#                  timestep               N of point      Surface temperature
#                     17000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022       1       5   10.44    0.13
#                  timestep               N of point      Surface temperature
#                     18000                        1                    255.8
#     Year   Month     Day    Hour  Months
#     2022       1       5   16.00    0.14
#                  timestep               N of point      Surface temperature
#                     19000                        1                    255.5
#     Year   Month     Day    Hour  Months
#     2022       1       5   21.56    0.14
#                  timestep               N of point      Surface temperature
#                     20000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1       6    3.11    0.15
#                  timestep               N of point      Surface temperature
#                     21000                        1                    255.0
#     Year   Month     Day    Hour  Months
#     2022       1       6    8.67    0.16
#                  timestep               N of point      Surface temperature
#                     22000                        1                    254.3
#     Year   Month     Day    Hour  Months
#     2022       1       6   14.22    0.17
#                  timestep               N of point      Surface temperature
#                     23000                        1                    252.8
#     Year   Month     Day    Hour  Months
#     2022       1       6   19.78    0.17
#                  timestep               N of point      Surface temperature
#                     24000                        1                    252.9
#     Year   Month     Day    Hour  Months
#     2022       1       7    1.33    0.18
#                  timestep               N of point      Surface temperature
#                     25000                        1                    253.5
#     Year   Month     Day    Hour  Months
#     2022       1       7    6.89    0.19
#                  timestep               N of point      Surface temperature
#                     26000                        1                    253.8
#     Year   Month     Day    Hour  Months
#     2022       1       7   12.44    0.20
#                  timestep               N of point      Surface temperature
#                     27000                        1                    252.7
#     Year   Month     Day    Hour  Months
#     2022       1       7   18.00    0.21
#                  timestep               N of point      Surface temperature
#                     28000                        1                    252.5
#     Year   Month     Day    Hour  Months
#     2022       1       7   23.56    0.21
#                  timestep               N of point      Surface temperature
#                     29000                        1                    252.7
#     Year   Month     Day    Hour  Months
#     2022       1       8    5.11    0.22
#                  timestep               N of point      Surface temperature
#                     30000                        1                    252.8
#     Year   Month     Day    Hour  Months
#     2022       1       8   10.67    0.23
#                  timestep               N of point      Surface temperature
#                     31000                        1                    252.7
#     Year   Month     Day    Hour  Months
#     2022       1       8   16.22    0.24
#                  timestep               N of point      Surface temperature
#                     32000                        1                    252.5
#     Year   Month     Day    Hour  Months
#     2022       1       8   21.78    0.24
#                  timestep               N of point      Surface temperature
#                     33000                        1                    252.3
#     Year   Month     Day    Hour  Months
#     2022       1       9    3.33    0.25
#                  timestep               N of point      Surface temperature
#                     34000                        1                    252.1
#     Year   Month     Day    Hour  Months
#     2022       1       9    8.89    0.26
#                  timestep               N of point      Surface temperature
#                     35000                        1                    252.1
#     Year   Month     Day    Hour  Months
#     2022       1       9   14.44    0.27
#                  timestep               N of point      Surface temperature
#                     36000                        1                    252.1
#     Year   Month     Day    Hour  Months
#     2022       1       9   20.00    0.27
#                  timestep               N of point      Surface temperature
#                     37000                        1                    252.2
#     Year   Month     Day    Hour  Months
#     2022       1      10    1.56    0.28
#                  timestep               N of point      Surface temperature
#                     38000                        1                    252.4
#     Year   Month     Day    Hour  Months
#     2022       1      10    7.11    0.29
#                  timestep               N of point      Surface temperature
#                     39000                        1                    252.6
#     Year   Month     Day    Hour  Months
#     2022       1      10   12.67    0.30
#                  timestep               N of point      Surface temperature
#                     40000                        1                    252.9
#     Year   Month     Day    Hour  Months
#     2022       1      10   18.22    0.30
#                  timestep               N of point      Surface temperature
#                     41000                        1                    253.3
#     Year   Month     Day    Hour  Months
#     2022       1      10   23.78    0.31
#                  timestep               N of point      Surface temperature
#                     42000                        1                    253.7
#     Year   Month     Day    Hour  Months
#     2022       1      11    5.33    0.32
#                  timestep               N of point      Surface temperature
#                     43000                        1                    254.2
#     Year   Month     Day    Hour  Months
#     2022       1      11   10.89    0.33
#  LAKE model: control point written successfully!
#                  timestep               N of point      Surface temperature
#                     44000                        1                    254.5
#     Year   Month     Day    Hour  Months
#     2022       1      11   16.44    0.33
#                  timestep               N of point      Surface temperature
#                     45000                        1                    254.8
#     Year   Month     Day    Hour  Months
#     2022       1      11   22.00    0.34
#                  timestep               N of point      Surface temperature
#                     46000                        1                    255.0
#     Year   Month     Day    Hour  Months
#     2022       1      12    3.56    0.35
#                  timestep               N of point      Surface temperature
#                     47000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      12    9.11    0.36
#                  timestep               N of point      Surface temperature
#                     48000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      12   14.67    0.37
#                  timestep               N of point      Surface temperature
#                     49000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      12   20.22    0.37
#                  timestep               N of point      Surface temperature
#                     50000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      13    1.78    0.38
#                  timestep               N of point      Surface temperature
#                     51000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      13    7.33    0.39
#                  timestep               N of point      Surface temperature
#                     52000                        1                    255.0
#     Year   Month     Day    Hour  Months
#     2022       1      13   12.89    0.40
#                  timestep               N of point      Surface temperature
#                     53000                        1                    255.0
#     Year   Month     Day    Hour  Months
#     2022       1      13   18.44    0.40
#                  timestep               N of point      Surface temperature
#                     54000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      14    0.00    0.41
#                  timestep               N of point      Surface temperature
#                     55000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      14    5.56    0.42
#                  timestep               N of point      Surface temperature
#                     56000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      14   11.11    0.43
#                  timestep               N of point      Surface temperature
#                     57000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      14   16.67    0.43
#                  timestep               N of point      Surface temperature
#                     58000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      14   22.22    0.44
#                  timestep               N of point      Surface temperature
#                     59000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      15    3.78    0.45
#                  timestep               N of point      Surface temperature
#                     60000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      15    9.33    0.46
#                  timestep               N of point      Surface temperature
#                     61000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      15   14.89    0.46
#                  timestep               N of point      Surface temperature
#                     62000                        1                    254.9
#     Year   Month     Day    Hour  Months
#     2022       1      15   20.44    0.47
#                  timestep               N of point      Surface temperature
#                     63000                        1                    254.6
#     Year   Month     Day    Hour  Months
#     2022       1      16    2.00    0.48
#                  timestep               N of point      Surface temperature
#                     64000                        1                    254.3
#     Year   Month     Day    Hour  Months
#     2022       1      16    7.56    0.49
#                  timestep               N of point      Surface temperature
#                     65000                        1                    254.0
#     Year   Month     Day    Hour  Months
#     2022       1      16   13.11    0.49
#                  timestep               N of point      Surface temperature
#                     66000                        1                    253.9
#     Year   Month     Day    Hour  Months
#     2022       1      16   18.67    0.50
#                  timestep               N of point      Surface temperature
#                     67000                        1                    253.7
#     Year   Month     Day    Hour  Months
#     2022       1      17    0.22    0.51
#                  timestep               N of point      Surface temperature
#                     68000                        1                    253.6
#     Year   Month     Day    Hour  Months
#     2022       1      17    5.78    0.52
#                  timestep               N of point      Surface temperature
#                     69000                        1                    253.4
#     Year   Month     Day    Hour  Months
#     2022       1      17   11.33    0.52
#                  timestep               N of point      Surface temperature
#                     70000                        1                    253.3
#     Year   Month     Day    Hour  Months
#     2022       1      17   16.89    0.53
#                  timestep               N of point      Surface temperature
#                     71000                        1                    253.3
#     Year   Month     Day    Hour  Months
#     2022       1      17   22.44    0.54
#                  timestep               N of point      Surface temperature
#                     72000                        1                    253.2
#     Year   Month     Day    Hour  Months
#     2022       1      18    4.00    0.55
#                  timestep               N of point      Surface temperature
#                     73000                        1                    253.1
#     Year   Month     Day    Hour  Months
#     2022       1      18    9.56    0.56
#                  timestep               N of point      Surface temperature
#                     74000                        1                    252.9
#     Year   Month     Day    Hour  Months
#     2022       1      18   15.11    0.56
#                  timestep               N of point      Surface temperature
#                     75000                        1                    252.5
#     Year   Month     Day    Hour  Months
#     2022       1      18   20.67    0.57
#                  timestep               N of point      Surface temperature
#                     76000                        1                    252.1
#     Year   Month     Day    Hour  Months
#     2022       1      19    2.22    0.58
#                  timestep               N of point      Surface temperature
#                     77000                        1                    251.8
#     Year   Month     Day    Hour  Months
#     2022       1      19    7.78    0.59
#                  timestep               N of point      Surface temperature
#                     78000                        1                    251.5
#     Year   Month     Day    Hour  Months
#     2022       1      19   13.33    0.59
#                  timestep               N of point      Surface temperature
#                     79000                        1                    251.7
#     Year   Month     Day    Hour  Months
#     2022       1      19   18.89    0.60
#                  timestep               N of point      Surface temperature
#                     80000                        1                    251.9
#     Year   Month     Day    Hour  Months
#     2022       1      20    0.44    0.61
#                  timestep               N of point      Surface temperature
#                     81000                        1                    252.2
#     Year   Month     Day    Hour  Months
#     2022       1      20    6.00    0.62
#                  timestep               N of point      Surface temperature
#                     82000                        1                    252.4
#     Year   Month     Day    Hour  Months
#     2022       1      20   11.56    0.62
#                  timestep               N of point      Surface temperature
#                     83000                        1                    252.7
#     Year   Month     Day    Hour  Months
#     2022       1      20   17.11    0.63
#                  timestep               N of point      Surface temperature
#                     84000                        1                    253.1
#     Year   Month     Day    Hour  Months
#     2022       1      20   22.67    0.64
#                  timestep               N of point      Surface temperature
#                     85000                        1                    253.6
#     Year   Month     Day    Hour  Months
#     2022       1      21    4.22    0.65
#                  timestep               N of point      Surface temperature
#                     86000                        1                    253.9
#     Year   Month     Day    Hour  Months
#     2022       1      21    9.78    0.65
#  LAKE model: control point written successfully!
#                  timestep               N of point      Surface temperature
#                     87000                        1                    254.1
#     Year   Month     Day    Hour  Months
#     2022       1      21   15.33    0.66
#                  timestep               N of point      Surface temperature
#                     88000                        1                    254.1
#     Year   Month     Day    Hour  Months
#     2022       1      21   20.89    0.67
#                  timestep               N of point      Surface temperature
#                     89000                        1                    254.2
#     Year   Month     Day    Hour  Months
#     2022       1      22    2.44    0.68
#                  timestep               N of point      Surface temperature
#                     90000                        1                    254.1
#     Year   Month     Day    Hour  Months
#     2022       1      22    8.00    0.68
#                  timestep               N of point      Surface temperature
#                     91000                        1                    253.9
#     Year   Month     Day    Hour  Months
#     2022       1      22   13.56    0.69
#                  timestep               N of point      Surface temperature
#                     92000                        1                    253.4
#     Year   Month     Day    Hour  Months
#     2022       1      22   19.11    0.70
#                  timestep               N of point      Surface temperature
#                     93000                        1                    252.6
#     Year   Month     Day    Hour  Months
#     2022       1      23    0.67    0.71
#                  timestep               N of point      Surface temperature
#                     94000                        1                    251.9
#     Year   Month     Day    Hour  Months
#     2022       1      23    6.22    0.71
#                  timestep               N of point      Surface temperature
#                     95000                        1                    251.6
#     Year   Month     Day    Hour  Months
#     2022       1      23   11.78    0.72
#                  timestep               N of point      Surface temperature
#                     96000                        1                    251.7
#     Year   Month     Day    Hour  Months
#     2022       1      23   17.33    0.73
#                  timestep               N of point      Surface temperature
#                     97000                        1                    252.1
#     Year   Month     Day    Hour  Months
#     2022       1      23   22.89    0.74
#                  timestep               N of point      Surface temperature
#                     98000                        1                    252.9
#     Year   Month     Day    Hour  Months
#     2022       1      24    4.44    0.75
#                  timestep               N of point      Surface temperature
#                     99000                        1                    253.7
#     Year   Month     Day    Hour  Months
#     2022       1      24   10.00    0.75
#                  timestep               N of point      Surface temperature
#                    100000                        1                    254.1
#     Year   Month     Day    Hour  Months
#     2022       1      24   15.56    0.76
#                  timestep               N of point      Surface temperature
#                    101000                        1                    254.3
#     Year   Month     Day    Hour  Months
#     2022       1      24   21.11    0.77
#                  timestep               N of point      Surface temperature
#                    102000                        1                    254.6
#     Year   Month     Day    Hour  Months
#     2022       1      25    2.67    0.78
#                  timestep               N of point      Surface temperature
#                    103000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      25    8.22    0.78
#                  timestep               N of point      Surface temperature
#                    104000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022       1      25   13.78    0.79
#                  timestep               N of point      Surface temperature
#                    105000                        1                    254.4
#     Year   Month     Day    Hour  Months
#     2022       1      25   19.33    0.80
#                  timestep               N of point      Surface temperature
#                    106000                        1                    247.0
#     Year   Month     Day    Hour  Months
#     2022       1      26    0.89    0.81
#                  timestep               N of point      Surface temperature
#                    107000                        1                    253.5
#     Year   Month     Day    Hour  Months
#     2022       1      26    6.44    0.81
#                  timestep               N of point      Surface temperature
#                    108000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      26   12.00    0.82
#                  timestep               N of point      Surface temperature
#                    109000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      26   17.56    0.83
#                  timestep               N of point      Surface temperature
#                    110000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      26   23.11    0.84
#                  timestep               N of point      Surface temperature
#                    111000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      27    4.67    0.84
#                  timestep               N of point      Surface temperature
#                    112000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022       1      27   10.22    0.85
#                  timestep               N of point      Surface temperature
#                    113000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      27   15.78    0.86
#                  timestep               N of point      Surface temperature
#                    114000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      27   21.33    0.87
#                  timestep               N of point      Surface temperature
#                    115000                        1                    255.4
#     Year   Month     Day    Hour  Months
#     2022       1      28    2.89    0.87
#                  timestep               N of point      Surface temperature
#                    116000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022       1      28    8.44    0.88
#                  timestep               N of point      Surface temperature
#                    117000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022       1      28   14.00    0.89
#                  timestep               N of point      Surface temperature
#                    118000                        1                    255.5
#     Year   Month     Day    Hour  Months
#     2022       1      28   19.56    0.90
#                  timestep               N of point      Surface temperature
#                    119000                        1                    255.4
#     Year   Month     Day    Hour  Months
#     2022       1      29    1.11    0.91
#                  timestep               N of point      Surface temperature
#                    120000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      29    6.67    0.91
#                  timestep               N of point      Surface temperature
#                    121000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      29   12.22    0.92
#                  timestep               N of point      Surface temperature
#                    122000                        1                    255.2
#     Year   Month     Day    Hour  Months
#     2022       1      29   17.78    0.93
#                  timestep               N of point      Surface temperature
#                    123000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022       1      29   23.33    0.94
#                  timestep               N of point      Surface temperature
#                    124000                        1                    255.4
#     Year   Month     Day    Hour  Months
#     2022       1      30    4.89    0.94
#                  timestep               N of point      Surface temperature
#                    125000                        1                    255.7
#     Year   Month     Day    Hour  Months
#     2022       1      30   10.44    0.95
#                  timestep               N of point      Surface temperature
#                    126000                        1                    256.2
#     Year   Month     Day    Hour  Months
#     2022       1      30   16.00    0.96
#                  timestep               N of point      Surface temperature
#                    127000                        1                    256.9
#     Year   Month     Day    Hour  Months
#     2022       1      30   21.56    0.97
#                  timestep               N of point      Surface temperature
#                    128000                        1                    257.7
#     Year   Month     Day    Hour  Months
#     2022       1      31    3.11    0.97
#                  timestep               N of point      Surface temperature
#                    129000                        1                    258.5
#     Year   Month     Day    Hour  Months
#     2022       1      31    8.67    0.98
#  LAKE model: control point written successfully!
#                  timestep               N of point      Surface temperature
#                    130000                        1                    259.1
#     Year   Month     Day    Hour  Months
#     2022       1      31   14.22    0.99
#                  timestep               N of point      Surface temperature
#                    131000                        1                    259.5
#     Year   Month     Day    Hour  Months
#     2022       1      31   19.78    1.00
#                  timestep               N of point      Surface temperature
#                    132000                        1                    260.0
#     Year   Month     Day    Hour  Months
#     2022       2       1    1.33    1.00
#                  timestep               N of point      Surface temperature
#                    133000                        1                    260.4
#     Year   Month     Day    Hour  Months
#     2022       2       1    6.89    1.01
#                  timestep               N of point      Surface temperature
#                    134000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       1   12.44    1.02
#                  timestep               N of point      Surface temperature
#                    135000                        1                    260.9
#     Year   Month     Day    Hour  Months
#     2022       2       1   18.00    1.03
#                  timestep               N of point      Surface temperature
#                    136000                        1                    261.0
#     Year   Month     Day    Hour  Months
#     2022       2       1   23.56    1.03
#                  timestep               N of point      Surface temperature
#                    137000                        1                    261.1
#     Year   Month     Day    Hour  Months
#     2022       2       2    5.11    1.04
#                  timestep               N of point      Surface temperature
#                    138000                        1                    261.2
#     Year   Month     Day    Hour  Months
#     2022       2       2   10.67    1.05
#                  timestep               N of point      Surface temperature
#                    139000                        1                    261.1
#     Year   Month     Day    Hour  Months
#     2022       2       2   16.22    1.06
#                  timestep               N of point      Surface temperature
#                    140000                        1                    261.0
#     Year   Month     Day    Hour  Months
#     2022       2       2   21.78    1.06
#                  timestep               N of point      Surface temperature
#                    141000                        1                    260.9
#     Year   Month     Day    Hour  Months
#     2022       2       3    3.33    1.07
#                  timestep               N of point      Surface temperature
#                    142000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       3    8.89    1.08
#                  timestep               N of point      Surface temperature
#                    143000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       3   14.44    1.09
#                  timestep               N of point      Surface temperature
#                    144000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       3   20.00    1.10
#                  timestep               N of point      Surface temperature
#                    145000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       4    1.56    1.10
#                  timestep               N of point      Surface temperature
#                    146000                        1                    260.8
#     Year   Month     Day    Hour  Months
#     2022       2       4    7.11    1.11
#                  timestep               N of point      Surface temperature
#                    147000                        1                    260.7
#     Year   Month     Day    Hour  Months
#     2022       2       4   12.67    1.12
#                  timestep               N of point      Surface temperature
#                    148000                        1                    260.0
#     Year   Month     Day    Hour  Months
#     2022       2       4   18.22    1.13
#                  timestep               N of point      Surface temperature
#                    149000                        1                    259.2
#     Year   Month     Day    Hour  Months
#     2022       2       4   23.78    1.13
#                  timestep               N of point      Surface temperature
#                    150000                        1                    258.1
#     Year   Month     Day    Hour  Months
#     2022       2       5    5.33    1.14
#                  timestep               N of point      Surface temperature
#                    151000                        1                    257.2
#     Year   Month     Day    Hour  Months
#     2022       2       5   10.89    1.15
#                  timestep               N of point      Surface temperature
#                    152000                        1                    255.4
#     Year   Month     Day    Hour  Months
#     2022       2       5   16.44    1.16
#                  timestep               N of point      Surface temperature
#                    153000                        1                    252.7
#     Year   Month     Day    Hour  Months
#     2022       2       5   22.00    1.16
#                  timestep               N of point      Surface temperature
#                    154000                        1                    251.2
#     Year   Month     Day    Hour  Months
#     2022       2       6    3.56    1.17
#                  timestep               N of point      Surface temperature
#                    155000                        1                    250.1
#     Year   Month     Day    Hour  Months
#     2022       2       6    9.11    1.18
#                  timestep               N of point      Surface temperature
#                    156000                        1                    248.5
#     Year   Month     Day    Hour  Months
#     2022       2       6   14.67    1.19
#                  timestep               N of point      Surface temperature
#                    157000                        1                    246.0
#     Year   Month     Day    Hour  Months
#     2022       2       6   20.22    1.19
#                  timestep               N of point      Surface temperature
#                    158000                        1                    242.2
#     Year   Month     Day    Hour  Months
#     2022       2       7    1.78    1.20
#                  timestep               N of point      Surface temperature
#                    159000                        1                    243.1
#     Year   Month     Day    Hour  Months
#     2022       2       7    7.33    1.21
#                  timestep               N of point      Surface temperature
#                    160000                        1                    242.8
#     Year   Month     Day    Hour  Months
#     2022       2       7   12.89    1.22
#                  timestep               N of point      Surface temperature
#                    161000                        1                    242.2
#     Year   Month     Day    Hour  Months
#     2022       2       7   18.44    1.22
#                  timestep               N of point      Surface temperature
#                    162000                        1                    241.7
#     Year   Month     Day    Hour  Months
#     2022       2       8    0.00    1.23
#                  timestep               N of point      Surface temperature
#                    163000                        1                    241.2
#     Year   Month     Day    Hour  Months
#     2022       2       8    5.56    1.24
#                  timestep               N of point      Surface temperature
#                    164000                        1                    240.7
#     Year   Month     Day    Hour  Months
#     2022       2       8   11.11    1.25
#                  timestep               N of point      Surface temperature
#                    165000                        1                    241.2
#     Year   Month     Day    Hour  Months
#     2022       2       8   16.67    1.25
#                  timestep               N of point      Surface temperature
#                    166000                        1                    241.9
#     Year   Month     Day    Hour  Months
#     2022       2       8   22.22    1.26
#                  timestep               N of point      Surface temperature
#                    167000                        1                    242.6
#     Year   Month     Day    Hour  Months
#     2022       2       9    3.78    1.27
#                  timestep               N of point      Surface temperature
#                    168000                        1                    243.4
#     Year   Month     Day    Hour  Months
#     2022       2       9    9.33    1.28
#                  timestep               N of point      Surface temperature
#                    169000                        1                    244.2
#     Year   Month     Day    Hour  Months
#     2022       2       9   14.89    1.29
#                  timestep               N of point      Surface temperature
#                    170000                        1                    245.3
#     Year   Month     Day    Hour  Months
#     2022       2       9   20.44    1.29
#                  timestep               N of point      Surface temperature
#                    171000                        1                    247.2
#     Year   Month     Day    Hour  Months
#     2022       2      10    2.00    1.30
#                  timestep               N of point      Surface temperature
#                    172000                        1                    249.0
#     Year   Month     Day    Hour  Months
#     2022       2      10    7.56    1.31
#  LAKE model: control point written successfully!
#                  timestep               N of point      Surface temperature
#                    173000                        1                    250.6
#     Year   Month     Day    Hour  Months
#     2022       2      10   13.11    1.32
#                  timestep               N of point      Surface temperature
#                    174000                        1                    252.2
#     Year   Month     Day    Hour  Months
#     2022       2      10   18.67    1.32
#                  timestep               N of point      Surface temperature
#                    175000                        1                    253.9
#     Year   Month     Day    Hour  Months
#     2022       2      11    0.22    1.33
#                  timestep               N of point      Surface temperature
#                    176000                        1                    255.5
#     Year   Month     Day    Hour  Months
#     2022       2      11    5.78    1.34
#                  timestep               N of point      Surface temperature
#                    177000                        1                    257.0
#     Year   Month     Day    Hour  Months
#     2022       2      11   11.33    1.35
#                  timestep               N of point      Surface temperature
#                    178000                        1                    257.2
#     Year   Month     Day    Hour  Months
#     2022       2      11   16.89    1.35
#                  timestep               N of point      Surface temperature
#                    179000                        1                    257.2
#     Year   Month     Day    Hour  Months
#     2022       2      11   22.44    1.36
#                  timestep               N of point      Surface temperature
#                    180000                        1                    257.1
#     Year   Month     Day    Hour  Months
#     2022       2      12    4.00    1.37
#                  timestep               N of point      Surface temperature
#                    181000                        1                    257.1
#     Year   Month     Day    Hour  Months
#     2022       2      12    9.56    1.38
#                  timestep               N of point      Surface temperature
#                    182000                        1                    256.7
#     Year   Month     Day    Hour  Months
#     2022       2      12   15.11    1.38
#                  timestep               N of point      Surface temperature
#                    183000                        1                    256.0
#     Year   Month     Day    Hour  Months
#     2022       2      12   20.67    1.39
# ...
#     Year   Month     Day    Hour  Months
#     2022      12      17   12.00   11.50
#                  timestep               N of point      Surface temperature
#                   1513000                        1                    256.3
#     Year   Month     Day    Hour  Months
#     2022      12      17   17.56   11.51
#                  timestep               N of point      Surface temperature
#                   1514000                        1                    256.2
#     Year   Month     Day    Hour  Months
#     2022      12      17   23.11   11.51
#                  timestep               N of point      Surface temperature
#                   1515000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022      12      18    4.67   11.52
#                  timestep               N of point      Surface temperature
#                   1516000                        1                    255.9
#     Year   Month     Day    Hour  Months
#     2022      12      18   10.22   11.53
#                  timestep               N of point      Surface temperature
#                   1517000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022      12      18   15.78   11.54
#                  timestep               N of point      Surface temperature
#                   1518000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022      12      18   21.33   11.54
#                  timestep               N of point      Surface temperature
#                   1519000                        1                    254.6
#     Year   Month     Day    Hour  Months
#     2022      12      19    2.89   11.55
#                  timestep               N of point      Surface temperature
#                   1520000                        1                    254.0
#     Year   Month     Day    Hour  Months
#     2022      12      19    8.44   11.56
#                  timestep               N of point      Surface temperature
#                   1521000                        1                    253.5
#     Year   Month     Day    Hour  Months
#     2022      12      19   14.00   11.57
#                  timestep               N of point      Surface temperature
#                   1522000                        1                    253.0
#     Year   Month     Day    Hour  Months
#     2022      12      19   19.56   11.58
#                  timestep               N of point      Surface temperature
#                   1523000                        1                    252.5
#     Year   Month     Day    Hour  Months
#     2022      12      20    1.11   11.58
#                  timestep               N of point      Surface temperature
#                   1524000                        1                    252.0
#     Year   Month     Day    Hour  Months
#     2022      12      20    6.67   11.59
#                  timestep               N of point      Surface temperature
#                   1525000                        1                    251.5
#     Year   Month     Day    Hour  Months
#     2022      12      20   12.22   11.60
#                  timestep               N of point      Surface temperature
#                   1526000                        1                    251.9
#     Year   Month     Day    Hour  Months
#     2022      12      20   17.78   11.61
#                  timestep               N of point      Surface temperature
#                   1527000                        1                    252.2
#     Year   Month     Day    Hour  Months
#     2022      12      20   23.33   11.61
#                  timestep               N of point      Surface temperature
#                   1528000                        1                    252.6
#     Year   Month     Day    Hour  Months
#     2022      12      21    4.89   11.62
#                  timestep               N of point      Surface temperature
#                   1529000                        1                    252.9
#     Year   Month     Day    Hour  Months
#     2022      12      21   10.44   11.63
#                  timestep               N of point      Surface temperature
#                   1530000                        1                    253.8
#     Year   Month     Day    Hour  Months
#     2022      12      21   16.00   11.64
#                  timestep               N of point      Surface temperature
#                   1531000                        1                    254.8
#     Year   Month     Day    Hour  Months
#     2022      12      21   21.56   11.64
#                  timestep               N of point      Surface temperature
#                   1532000                        1                    255.9
#     Year   Month     Day    Hour  Months
#     2022      12      22    3.11   11.65
#                  timestep               N of point      Surface temperature
#                   1533000                        1                    256.9
#     Year   Month     Day    Hour  Months
#     2022      12      22    8.67   11.66
#                  timestep               N of point      Surface temperature
#                   1534000                        1                    257.5
#     Year   Month     Day    Hour  Months
#     2022      12      22   14.22   11.67
#                  timestep               N of point      Surface temperature
#                   1535000                        1                    257.6
#     Year   Month     Day    Hour  Months
#     2022      12      22   19.78   11.67
#                  timestep               N of point      Surface temperature
#                   1536000                        1                    257.6
#     Year   Month     Day    Hour  Months
#     2022      12      23    1.33   11.68
#                  timestep               N of point      Surface temperature
#                   1537000                        1                    257.7
#     Year   Month     Day    Hour  Months
#     2022      12      23    6.89   11.69
#                  timestep               N of point      Surface temperature
#                   1538000                        1                    257.7
#     Year   Month     Day    Hour  Months
#     2022      12      23   12.44   11.70
#                  timestep               N of point      Surface temperature
#                   1539000                        1                    257.0
#     Year   Month     Day    Hour  Months
#     2022      12      23   18.00   11.70
#                  timestep               N of point      Surface temperature
#                   1540000                        1                    256.3
#     Year   Month     Day    Hour  Months
#     2022      12      23   23.56   11.71
#                  timestep               N of point      Surface temperature
#                   1541000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022      12      24    5.11   11.72
#                  timestep               N of point      Surface temperature
#                   1542000                        1                    254.9
#     Year   Month     Day    Hour  Months
#     2022      12      24   10.67   11.73
#                  timestep               N of point      Surface temperature
#                   1543000                        1                    254.7
#     Year   Month     Day    Hour  Months
#     2022      12      24   16.22   11.73
#                  timestep               N of point      Surface temperature
#                   1544000                        1                    254.6
#     Year   Month     Day    Hour  Months
#     2022      12      24   21.78   11.74
#                  timestep               N of point      Surface temperature
#                   1545000                        1                    254.4
#     Year   Month     Day    Hour  Months
#     2022      12      25    3.33   11.75
#                  timestep               N of point      Surface temperature
#                   1546000                        1                    254.4
#     Year   Month     Day    Hour  Months
#     2022      12      25    8.89   11.76
#                  timestep               N of point      Surface temperature
#                   1547000                        1                    254.5
#     Year   Month     Day    Hour  Months
#     2022      12      25   14.44   11.77
#                  timestep               N of point      Surface temperature
#                   1548000                        1                    254.9
#     Year   Month     Day    Hour  Months
#     2022      12      25   20.00   11.77
#                  timestep               N of point      Surface temperature
#                   1549000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022      12      26    1.56   11.78
#                  timestep               N of point      Surface temperature
#                   1550000                        1                    255.7
#     Year   Month     Day    Hour  Months
#     2022      12      26    7.11   11.79
#                  timestep               N of point      Surface temperature
#                   1551000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022      12      26   12.67   11.80
#                  timestep               N of point      Surface temperature
#                   1552000                        1                    255.9
#     Year   Month     Day    Hour  Months
#     2022      12      26   18.22   11.80
#                  timestep               N of point      Surface temperature
#                   1553000                        1                    255.6
#     Year   Month     Day    Hour  Months
#     2022      12      26   23.78   11.81
#                  timestep               N of point      Surface temperature
#                   1554000                        1                    255.3
#     Year   Month     Day    Hour  Months
#     2022      12      27    5.33   11.82
#                  timestep               N of point      Surface temperature
#                   1555000                        1                    255.1
#     Year   Month     Day    Hour  Months
#     2022      12      27   10.89   11.83
#  LAKE model: control point written successfully!
#                  timestep               N of point      Surface temperature
#                   1556000                        1                    254.8
#     Year   Month     Day    Hour  Months
#     2022      12      27   16.44   11.83
#                  timestep               N of point      Surface temperature
#                   1557000                        1                    254.6
#     Year   Month     Day    Hour  Months
#     2022      12      27   22.00   11.84
#                  timestep               N of point      Surface temperature
#                   1558000                        1                    254.3
#     Year   Month     Day    Hour  Months
#     2022      12      28    3.56   11.85
#                  timestep               N of point      Surface temperature
#                   1559000                        1                    254.2
#     Year   Month     Day    Hour  Months
#     2022      12      28    9.11   11.86
#                  timestep               N of point      Surface temperature
#                   1560000                        1                    254.2
#     Year   Month     Day    Hour  Months
#     2022      12      28   14.67   11.86
#                  timestep               N of point      Surface temperature
#                   1561000                        1                    254.3
#     Year   Month     Day    Hour  Months
#     2022      12      28   20.22   11.87
#                  timestep               N of point      Surface temperature
#                   1562000                        1                    254.4
#     Year   Month     Day    Hour  Months
#     2022      12      29    1.78   11.88
#                  timestep               N of point      Surface temperature
#                   1563000                        1                    254.5
#     Year   Month     Day    Hour  Months
#     2022      12      29    7.33   11.89
#                  timestep               N of point      Surface temperature
#                   1564000                        1                    254.8
#     Year   Month     Day    Hour  Months
#     2022      12      29   12.89   11.89
#                  timestep               N of point      Surface temperature
#                   1565000                        1                    255.4
#     Year   Month     Day    Hour  Months
#     2022      12      29   18.44   11.90
#                  timestep               N of point      Surface temperature
#                   1566000                        1                    256.1
#     Year   Month     Day    Hour  Months
#     2022      12      30    0.00   11.91
#                  timestep               N of point      Surface temperature
#                   1567000                        1                    256.7
#     Year   Month     Day    Hour  Months
#     2022      12      30    5.56   11.92
#                  timestep               N of point      Surface temperature
#                   1568000                        1                    257.4
#     Year   Month     Day    Hour  Months
#     2022      12      30   11.11   11.92
#                  timestep               N of point      Surface temperature
#                   1569000                        1                    257.8
#     Year   Month     Day    Hour  Months
#     2022      12      30   16.67   11.93
#                  timestep               N of point      Surface temperature
#                   1570000                        1                    258.1
#     Year   Month     Day    Hour  Months
#     2022      12      30   22.22   11.94
#                  timestep               N of point      Surface temperature
#                   1571000                        1                    258.4
#     Year   Month     Day    Hour  Months
#     2022      12      31    3.78   11.95
#                  timestep               N of point      Surface temperature
#                   1572000                        1                    258.8
#     Year   Month     Day    Hour  Months
#     2022      12      31    9.33   11.96
#                  timestep               N of point      Surface temperature
#                   1573000                        1                    259.0
#     Year   Month     Day    Hour  Months
#     2022      12      31   14.89   11.96
#                  timestep               N of point      Surface temperature
#                   1574000                        1                    259.0
#     Year   Month     Day    Hour  Months
#     2022      12      31   20.44   11.97
#            1 years left
#                  timestep               N of point      Surface temperature
#                   1575000                        1                    259.0
#     Year   Month     Day    Hour  Months
#     2023       1       1    2.00   11.98
#                  timestep               N of point      Surface temperature
#                   1576000                        1                    259.1
#     Year   Month     Day    Hour  Months
#     2023       1       1    7.56   11.99
#  An error while reading ASCII forcing file.  iostat =         5001
#  The integration finished successfully
#  The time of integration is    454.76232100048918      sec
#
# Copying files from results/YKD1 to results/YKD1
# Copying files from results/YKD1 to results/YKD1
# Skipping copying results/YKD1/time_series to results/YKD1/time_series as it's the same file.
# Skipping copying results/YKD1/daily to results/YKD1/daily as it's the same file.
# Skipping copying results/YKD1/netcdf to results/YKD1/netcdf as it's the same file.
# Skipping copying results/YKD1/hourly to results/YKD1/hourly as it's the same file.
# Skipping copying results/YKD1/everystep to results/YKD1/everystep as it's the same file.
# Skipping copying results/YKD1/monthly to results/YKD1/monthly as it's the same file.
# All experiments completed successfully.

# %%
ls setup/driver_file_0.dat

# %%
ls
